# %%
import pandas as pd
import numpy as np 
import openpyxl
from pathlib import Path

# %%
#Import data
df1 = pd.read_excel(r'C:\Users\Acer\OneDrive - Institut Teknologi Bandung\Magang BI\Data\Web Scraping Hotel\data fix 2\data_fix_Yogyakarta2.xlsx', sheet_name="Hotel_1",engine = "openpyxl")
data1 = np.array(df1)
print(df1)

link = r'C:\Users\Acer\OneDrive - Institut Teknologi Bandung\Magang BI\Data\Web Scraping Hotel\data fix\data_fix_Yogyakarta.xlsx'
df2 = pd.read_excel(link, sheet_name="Hotel_2",engine = "openpyxl")
data2 = np.array(df2)
# Out:
#                                            Nama Hotel  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                         Hotel Citra
# 3   OYO 2285 Art Guest House Syariah Near RSUD Kot...
# 4   OYO 1626 Alena Residence Near RS Ludira Husada...
# 5           OYO 194 Hotel Sapta Gria Near RS Bethesda
# 6                          Penginapan Griya Watukelir
# 7                  Green Belt Near Bandara Adisucipto
# 8                                  OYO 90253 D'helomi
# 9                                  Hotel Cahaya Kasih
# 10   OYO 2394 Hotel Brosta Near RS Ludira Husada Tama
# 11   GRAND ASTON Hotel & Convention Center Yogyakarta
# 12                                   Kinasih Homestay
# 13                                      Omah Sastro 1
# 14  OYO 2008 Sellinas Family Residence  Near RSUP ...
# 15                        OYO 3819 Hotel Winotosastro
# ...

# %%
for i in range(2,len(data1[:,0])):
    for j in range(2,len(data2[:,0])):
        if data1[i,0] == data2[j,0]:
            #data1[i,3] = data2[j,3] #masukin alamat
            #data1[i,4] = data2[j,4] #masukin tipe
            #data1[i,56] = data2[j,71] #masukin fasilitas
            data1[i,56] = data2[j,71] #Masukin Latitude
            data1[i,57] = data2[j,72] #Masukin Longitude
            break

# %%
df_data = pd.DataFrame(data1)
print(df_data)
df_data.to_excel(r"C:\Users\Acer\Downloads\data_koordinat2.xlsx")
# Out:
#                                                    0   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                         Hotel Citra
# 3   OYO 2285 Art Guest House Syariah Near RSUD Kot...
# 4   OYO 1626 Alena Residence Near RS Ludira Husada...
# 5           OYO 194 Hotel Sapta Gria Near RS Bethesda
# 6                          Penginapan Griya Watukelir
# 7                  Green Belt Near Bandara Adisucipto
# 8                                  OYO 90253 D'helomi
# 9                                  Hotel Cahaya Kasih
# 10   OYO 2394 Hotel Brosta Near RS Ludira Husada Tama
# 11   GRAND ASTON Hotel & Convention Center Yogyakarta
# 12                                   Kinasih Homestay
# 13                                      Omah Sastro 1
# 14  OYO 2008 Sellinas Family Residence  Near RSUP ...
# 15                        OYO 3819 Hotel Winotosastro
# ...
